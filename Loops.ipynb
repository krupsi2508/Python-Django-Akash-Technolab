# %%
a = int(input("Enter your first value = "))
b = int(input("Enter your second value= "))

#Find average of 5 numbers.
sum = 0
for num in range(0, a+1, 1):
    sum = sum+num     
average = sum / a
print("SUM of", a, "numbers is: ", sum )
print("Average of", a, "natural number is: ", average)

#Check whether number is even or odd
if (a % 2 ) == 0:  
  print("{0} is Even number".format(a))  
else:  
   print("{0} is Odd number".format(a))

#Leap Year
year = int(input("Enter a year: "))  
if (year % 4) == 0:  
   if (year % 100) == 0:  
       if (year % 400) == 0:  
           print("{0} is a leap year".format(year))  
       else:  
           print("{0} is not a leap year".format(year))  
   else:  
       print("{0} is a leap year".format(year))  
else:  
   print("{0} is not a leap year".format(year))  

#Positive , Negative  & Zero
if b >= 0:
   if b == 0:
       print("Zero")
   else:
       print("Positive number")
else:
   print("Negative number")

#Greatest Number
if a >= b :
    print(a,"is a greater")
else:
    print(b,"is a greater")

#Factorial Number
factorial = 1    
if b < 0:    
   print(" Factorial does not exist for negative numbers")    
elif num == 0:    
   print("The factorial of 0 is 1")    
else:    
   for i in range(1,b + 1):    
       factorial = factorial*i    
   print("The factorial of",b,"is",factorial)  

#Swap two values using third value
temp = a
a = b
b = temp
print('The value of a after swapping: {}'.format(a))
print('The value of b after swapping: {}'.format(b))

#Find Smallest Number
print(min(a,b),"is smallest")

#Less than 100 and check even or odd

if a < 100 :
    print(a,"is less than 100")
    if (a % 2)==0:
        print(a," is even number")
    else:
        print(a,"is odd number")
else:
    print(a,"is greater than 100")
    
    
#print the square of a number if it is less than 10
if a < 10:
    print(a,"is less than 10")
    square =  a * a
    print("The Square of " ,a,"is",square)
# Out:
# Enter your first value = 20
# Enter your second value= 6
# SUM of 20 numbers is:  210
# Average of 20 natural number is:  10.5
# 20 is Even number
# Enter a year: 2021
# 2021 is not a leap year
# Positive number
# 20 is a greater
# The factorial of 6 is 720
# The value of a after swapping: 6
# The value of b after swapping: 20
# 6 is smallest
# 6 is less than 100
# 6  is even number
# 6 is less than 10
# The Square of  6 is 36

# %%
#largest among three
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if (a >= b) and (a >= c):
   largest = a
elif (b >= a) and (b >= a):
   largest = b
else:
   largest = c

print("The largest number is", largest)

#smallest among three
smallest = 0

if a < b and a < c :
    smallest = a
elif b < c :
    smallest = b
else :
    smallest = c

print(smallest, "is the smallest of three numbers.")
# Out:
# Enter first number: 20
# Enter second number: 25
# Enter third number: 12
# The largest number is 25
# 12 is the smallest of three numbers.
